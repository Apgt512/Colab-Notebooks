# %% [markdown]
# # Clase 30 Agosto 2021 #
# ### Matrices y sistemas de ecuaciones lineales ###

# %%
import numpy as np

# %%
(np.arange(10_000_000, dtype=np.int64)**2).sum()
# Out:
# 1291890006563070912

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
9223372036854775807
# Out:
# 9223372036854775807

# %%
2**64
# Out:
# 18446744073709551616

# %%
 18_446_744_073_709_551_615 > \
333_333_283_333_335_000_000
# Out:
# False

# %%
sum([i**2 for i in range(10_000_000)])
# Out:
# 333333283333335000000

# %% [markdown]
# https://www.python.org/dev/peps/pep-0237/
# https://levelup.gitconnected.com/how-python-represents-integers-using-bignum-f8f0574d0d6b

# %% [markdown]
# ### Matrices ###

# %%
# Transpuesta, suma, multiplicación escalar, multiplicación elemento a elemento y multiplicación de matrices

# %%
# Multiplicar una matriz por la matriz identidad

# %% [markdown]
# **Inversa de una matriz**: Es análogo a la inversa de un número.
# N es la inversa de la matriz M si:
# $M\cdot N=I$

# %% [markdown]
# **Determinante**: Propiedad de las matrices cuadradas. Nos indica si la matriz tiene inversa. Para una matriz de 2x2:
# $|M|=\begin{bmatrix}
# a & b\\
# c & d
# \end{bmatrix}=ad-bc$

# %% [markdown]
# **Rango**: El rango de una matriz A de m x n es el número de columnas o filas linealmente independientes.

# %% [markdown]
# Para dos vectores $x$ e $y$ y dos escalares $a$ y $b$, $F$ es una **transformación lineal** si:
# $F(ax+by)=aF(x)+bF(y)$

# %% [markdown]
# ### Ejercicios ###
# 1. Haz un ejemplo en el que verifiques que para las matrices se cumple la propiedad: $A(B+C)=AB+AC$.
# 2. Implementa usando un ciclo for la multiplicación de una matriz de 2x4 y una matriz de 4x3.
# 3. Una matriz de rotación está definida como:
# $R=\begin{bmatrix}
# \cos{\theta} & -\sin{\theta}\\
# \sin{\theta} & \cos{\theta}
# \end{bmatrix}$
# Utiliza una matriz de rotación para rotar el vector (1,1) en 90°.

# %% [markdown]
# 4. **(Convolución)** La convolución de un vector $a$ de tamaño n y un vector $b$ de tamaño m es el vector $c$ denotado por $a\ast b$ con elementos:
# $c_k=\sum_{i+j=k+1}a_i b_j, k=1,..,n+m-1$
# En el caso de matrices se puede generalizar, si $A$ es una matriz de m x n y $B$ es una matriz de p x q entonces $C$ será la matriz de (m+p-1)x(n+q-1) con la convolución
# ![image.png](attachment:image.png)
# Escribe un programa que realice convoluciones vectoriales y uno que realice convoluciones de matrices

# %% [markdown]
# ### Sistemas de ecuaciones lineales ###
# Una ecuación lineal es una igualdad que tiene la forma:
# $\sum{a_i x_i}=y$
# Un sistema de ecuaciones lineales es un set de ecuaciones lineales que comparten las mismas variables. Por ejemplo:
# $a_1x_1 + a_2x_2 = y_1$
# $a_3x_1 + a_4x_2 = y_2$
#
# La forma matricial de un sistema de ecuaciones lineales se expresa como $Ax=y$
# ![image.png](attachment:image.png)
